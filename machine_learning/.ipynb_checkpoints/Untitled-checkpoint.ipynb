# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('csvs/stock.csv') as f:
    sheet = pd.read_csv(f).drop(['Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6'],axis = 1)

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sheet)
