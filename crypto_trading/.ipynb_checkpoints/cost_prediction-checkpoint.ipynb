# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# C:\Users\SEO09\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = (30,10)

# %%
class Coin:
    
    def __init__(self):
        self.coins = 'TRX,NEO,BLZ,ICX,EOS,VEN,XRP,ADA,XLM,FUN,BNB,DGD,LTC,IOTA,CTR,WTC,CND,QSP,OMG,PPT,ZRX,IOST,GXS,XVG,BQX,LSK,REQ,POWR,POE,ELF,QTUM,ENG,BTS,AION,XMR,VIBE,SNT,KNC,ETC,MANA,VIB,LEND,SUB,OST,SALT,ZEC,ENJ,NEBL,HSR,NULS,LINK,BCD,LRC,WABI,TNB,GTO,ARK,TRIG,DASH,APPC,STRAT,MTL,SNGLS,MDA,INS,GVT,TNT,AST,BAT,BTG,MCO,CDT,LUN,ARN,AMB,WAVES,ADX,FUEL,BRD,RCN,XZC,MOD,NAV,EVX,DNT,KMD,BNT,ICN,BCPT,STORJ,DLT,EDO,WINGS,SNM,MTH,OAX,YOYO'.split(',')
        self.coin_dict = {}
        for i in self.coins:
            self.coin_dict[i] = pd.read_csv('data_csv/data_{}_KRW.csv'.format(i)).drop(['Unnamed: 0'], axis = 1)

class Index:
    
    def __init__(self, coin_dict, my_coin = 'ETH'):
        self.coin_dict = coin_dict
        self.my_coin = my_coin.upper()
        
        self.close = np.array(self.coin_dict[self.my_coin].close) + np.array(10e-12)
        self.volumeto = np.array(self.coin_dict[self.my_coin.upper()].volumeto) + np.array(10e-12)

    def close_del(self, interval = 24):
        close = self.close
        del_list = [(close[i+interval]-close[i])*100/close[i] for i in range(len(close)-interval)] # 가격 변화율
        self.close_del = np.array(del_list)
        return np.array(del_list)
    
    def volume_del(self, interval = 24):
        volumeto = self.volumeto
        del_list = [(volumeto[i+interval]-volumeto[i])*100/volumeto[i] for i in range(len(volumeto)-interval)] # 거래량 변화율
        self.volume_del = np.array(del_list)
        return np.array(del_list)
    
    def close_std(self, interval = 24): # 가격 표준편차 표준화
        close = self.close
        std_list = [np.std(close[i:i+interval])*100/np.mean(close[i:i+interval]) for i in range(len(close)-interval)]
        self.close_std = std_list
        return np.array(std_list)
    
    def volume_std(self, interval = 24): # 가격 표준편차 표준화
        volumeto = self.volumeto
        std_list = [np.std(volumeto[i:i+interval])*100/np.mean(volumeto[i:i+interval]) for i in range(len(volumeto)-interval)]
        self.volume_std = std_list
        return np.array(std_list)
    
    def moving_avg(self, interval = 24): #이동평균선
        close = self.close
        avg_list = [np.mean(close[i:i+interval]) for i in range(len(close)-interval)]
        self.moving_avg = avg_list
        return np.array(avg_list)
    
    def moving_std(self, interval = 24): #이동표준편차
        close = self.close
        std_list = [np.std(close[i:i+interval]) for i in range(len(close)-interval)]
        self.moving_std = std_list
        return np.array(std_list)
    
    def bolin_up(self, interval = 24): #볼린저 위
        close = self.close
        bolup_list = [np.mean(close[i:i+interval]) + (2*np.std(close[i:i+interval])) for i in range(len(close)-interval)]
        self.bolin_up = np.array(bolup_list)
        return np.array(bolup_list)
    
    def bolin_dn(self, interval = 24): #볼린저 아래
        close = self.close
        boldn_list = [np.mean(close[i:i+interval]) - (2*np.std(close[i:i+interval])) for i in range(len(close)-interval)]
        self.bolin_dn = np.array(boldn_list)
        return np.array(boldn_list)
    

class Learn: # 머신러닝
    
    def __init__(self, hidden_dim = 20, seq_length = 24):
        self.hidden_dim = hidden_dim
        self.seq_length = 24
        
    def process(self, x, y):
        print('processing started')

        self.data_dim = x.shape[1]
        self.output_dim = y.shape[1]
        
        self.dataX = []
        self.dataY = []
        
        for i in range(len(y) - self.seq_length):
            _x = np.array(x)[i:i+self.seq_length]
            _y = np.array(y)[i]
            self.dataX.append(_x) # data with previous data
            self.dataY.append(_y) # label
        print('Data processed')

    def learn(self, trainX, trainY, iteration = 2000):
        
        
        self.X = tf.placeholder(tf.float32, [None, self.seq_length, self.data_dim])
        self.Y = tf.placeholder(tf.float32, [None,self.output_dim])
         
        cell = tf.contrib.rnn.BasicLSTMCell(num_units = self.hidden_dim, state_is_tuple = True)
        output, state = tf.nn.dynamic_rnn(cell, self.X, dtype = tf.float32)
        self.Y_pred = tf.contrib.layers.fully_connected(output[:,-1], self.output_dim, activation_fn = None)
        print('RNN initiated')
        
        loss = tf.reduce_sum(tf.square(self.Y_pred - self.Y))

        opt = tf.train.AdamOptimizer(0.01)
        train = opt.minimize(loss)
        
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        print('initialized')
        
        for i in range(iteration):
            tr, l = self.sess.run([train, loss], feed_dict = {self.X: trainX, self.Y: trainY})
            if i%10 == 0:
                print('Process {0:.2f}% done.'.format(i*100/iteration), end = '\r')
            elif i == iteration-1:
                print('Process 100% done.    ', end = '\n')
        print('Done!')
                

    def predict(self, testX):
        
        testPred = self.sess.run(self.Y_pred, feed_dict = {self.X: testX})
        print('Test data predicted')
        
        self.testPred = testPred
        return testPred

# %%
coins = Coin()

# %%
ada = Index(coins.coin_dict, 'ADA') # 인터벌은 각 지표마다 따로 넣는게 좋은 듯..

# %%
price_del = ada.close_del(interval = 24)
volume_del = ada.volume_del(interval = 24)
price_std = ada.close_std(interval = 24)
volume_std = ada.volume_std(interval = 24) # make sure to have the same dimension!

# %%
x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
y = np.array([price_del]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)

# %%
ada_learn = Learn()

# %%
ada_learn.process(x,y)
# Out:
# processing started
# Data processed

# %%
train_size = int(len(ada_learn.dataY) * 0.7)
test_size = len(ada_learn.dataY) - train_size

trainX, testX = np.array(ada_learn.dataX[0:train_size]), np.array(ada_learn.dataX[train_size:len(ada_learn.dataX)])
trainY, testY = np.array(ada_learn.dataY[0:train_size]), np.array(ada_learn.dataY[train_size:len(ada_learn.dataX)])

# %%
ada_learn.learn(trainX, trainY, iteration = 2000)
# Out:
# RNN initiated
# initialized
# Process 100% done.
# Done!

# %%
#pred = ada_learn.predict(testX)
pred = ada_learn.predict(np.array(ada_learn.dataX))
# Out:
# Test data predicted

# %%
plt.plot(pred) # blue

#plt.plot(testY) # orange
plt.plot(np.array(ada_learn.dataY))

plt.show()

# %%
len(ada.close[49:])
# Out:
# 1952

# %%
len(pred)
# Out:
# 1953

# %%
ada_price = ada.close[50:]
plt.plot(ada_price) # blue
buy = [ada_price[i] if pred[i] > 15 else None for i in range(len(pred)) ] # red # 10퍼증가할 확률 큰 지점

sell_5 = [ada_price[i] if pred[i] < -5 else None for i in range(len(pred)) ] # cyan # 5퍼 떨어질 확률 큰 지점
sell_10 = [ada_price[i] if pred[i] < -10 else None for i in range(len(pred)) ] # blue # 10퍼 떨어짐 
plt.plot(buy, 'ro')

plt.plot(sell_5, 'co')
plt.plot(sell_10, 'bo')
plt.show()

# %%
import Crawl as c

# %%
xrp = c.Coin(['XRP'], limit = 2000)

# %%
xrp.process()
# Out:
# Coin data for XRP crawled. 1 of 1
# File for XRP successfully saved

# %%
ripple = Index(coins.coin_dict, 'XRP')

price_del = ripple.close_del(interval = 48)
volume_del = ripple.volume_del(interval = 48)
price_std = ripple.close_std(interval = 48)
volume_std = ripple.volume_std(interval = 48) # make sure to have the same dimension!

x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
y = np.array([price_del[1:]]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)

xrp_learn = Learn()
xrp_learn.process(x,y)

pred = ada_learn.predict(np.array(xrp_learn.dataX))

xrp_price = ripple.close[:1900]
plt.plot(xrp_price) # blue
buy = [xrp_price[i] if pred[i] > 5 else None for i in range(len(xrp_price)) ] # red # 10퍼증가할 확률 큰 지점

sell_0 = [xrp_price[i] if pred[i] < -3 else None for i in range(len(xrp_price)) ] # green # 5퍼 떨어질 확률 큰 지점
sell_5 = [xrp_price[i] if pred[i] < -5 else None for i in range(len(xrp_price)) ] # cyan # 5퍼 떨어질 확률 큰 지점
sell_10 = [xrp_price[i] if pred[i] < -10 else None for i in range(len(xrp_price)) ] # blue # 10퍼 떨어짐 
plt.plot(buy, 'ro')

plt.plot(sell_0, 'go')
plt.plot(sell_5, 'co')
plt.plot(sell_10, 'bo')
plt.show()
# Out:
# processing started
# Data processed
# Test data predicted

# %%
plt.close()

# %%
btg = c.Coin(['BTG'], limit = 2000)

btg.process()

btg = Index(coins.coin_dict, 'BTG')

price_del = btg.close_del(interval = 48)
volume_del = btg.volume_del(interval = 48)
price_std = btg.close_std(interval = 48)
volume_std = btg.volume_std(interval = 48) # make sure to have the same dimension!

x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
y = np.array([price_del[1:]]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)

btg_learn = Learn()
btg_learn.process(x,y)

pred = ada_learn.predict(np.array(btg_learn.dataX))

btg_price = btg.close[:1900]
plt.plot(btg_price) # blue
buy = [btg_price[i] if pred[i] > 5 else None for i in range(len(btg_price)) ] # red # 10퍼증가할 확률 큰 지점

sell_0 = [btg_price[i] if pred[i] < -3 else None for i in range(len(btg_price)) ] # green # 5퍼 떨어질 확률 큰 지점
sell_5 = [btg_price[i] if pred[i] < -5 else None for i in range(len(btg_price)) ] # cyan # 5퍼 떨어질 확률 큰 지점
sell_10 = [btg_price[i] if pred[i] < -10 else None for i in range(len(btg_price)) ] # blue # 10퍼 떨어짐 
plt.plot(buy, 'ro')


plt.plot(sell_0, 'go')
plt.plot(sell_5, 'co')
plt.plot(sell_10, 'bo')
plt.show()
# Out:
# Coin data for BTG crawled. 1 of 1
# File for BTG successfully saved
# processing started
# Data processed
# Test data predicted

# %%
eos = c.Coin(['EOS'], limit = 2000)

eos.process()

eos = Index(coins.coin_dict, 'EOS')

price_del = eos.close_del(interval = 48)
volume_del = eos.volume_del(interval = 48)
price_std = eos.close_std(interval = 48)
volume_std = eos.volume_std(interval = 48) # make sure to have the same dimension!

x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
y = np.array([price_del[1:]]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)

eos_learn = Learn()
eos_learn.process(x,y)

pred = ada_learn.predict(np.array(eos_learn.dataX))

eos_price = eos.close[:1900]
plt.plot(eos_price) # blue
buy = [eos_price[i] if pred[i] > 5 else None for i in range(len(eos_price)) ] # red # 10퍼증가할 확률 큰 지점

sell_0 = [eos_price[i] if pred[i] < -3 else None for i in range(len(eos_price)) ] # green # 5퍼 떨어질 확률 큰 지점
sell_5 = [eos_price[i] if pred[i] < -5 else None for i in range(len(eos_price)) ] # cyan # 5퍼 떨어질 확률 큰 지점
sell_10 = [eos_price[i] if pred[i] < -10 else None for i in range(len(eos_price)) ] # blue # 10퍼 떨어짐 
plt.plot(buy, 'ro')


plt.plot(sell_0, 'go')
plt.plot(sell_5, 'co')
plt.plot(sell_10, 'bo')
plt.show()
# Out:
# Coin data for EOS crawled. 1 of 1
# File for EOS successfully saved
# processing started
# Data processed
# Test data predicted

# %%
qtm = c.Coin(['QTUM'], limit = 2000)

qtm.process()

qtm = Index(coins.coin_dict, 'QTUM')

price_del = qtm.close_del(interval = 48)
volume_del = qtm.volume_del(interval = 48)
price_std = qtm.close_std(interval = 48)
volume_std = qtm.volume_std(interval = 48) # make sure to have the same dimension!

x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
y = np.array([price_del[1:]]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)

qtm_learn = Learn()
qtm_learn.process(x,y)

pred = ada_learn.predict(np.array(qtm_learn.dataX))

qtm_price = qtm.close[:1900]
plt.plot(qtm_price) # blue
buy = [qtm_price[i] if pred[i] > 5 else None for i in range(len(qtm_price)) ] # red # 10퍼증가할 확률 큰 지점

sell_0 = [qtm_price[i] if pred[i] < -3 else None for i in range(len(qtm_price)) ] # green # 5퍼 떨어질 확률 큰 지점
sell_5 = [qtm_price[i] if pred[i] < -5 else None for i in range(len(qtm_price)) ] # cyan # 5퍼 떨어질 확률 큰 지점
sell_10 = [qtm_price[i] if pred[i] < -10 else None for i in range(len(qtm_price)) ] # blue # 10퍼 떨어짐 

plt.plot(buy, 'ro')


plt.plot(sell_0, 'go')
plt.plot(sell_5, 'co')
plt.plot(sell_10, 'bo')
plt.show()
# Out:
# Coin data for QTUM crawled. 1 of 1
# File for QTUM successfully saved
# processing started
# Data processed
# Test data predicted

# %%
import Crawl as c

coin_dict = {}
coin_index = {}

for i in coin_lists:
    
    coin = c.Coin([i], limit = 2000)
    coin.process()
    
    index = Index(coins.coin_dict, i)
    
    
    price_del = index.close_del()
    volume_del = index.volume_del()
    price_std = index.close_std()
    volume_std = index.volume_std()
    
    x = np.array([price_del, volume_del, price_std, volume_std]).T # 학습에 쓰이는 데이터
    y = np.array([price_del[1:]]).T #답(24시간동안의 양상을 바탕으로 다음 1시간후(25시간)의 상승률)
    
    learn = Learn()
    learn.process(x,y)
    
    pred = ada_learn.predict(np.array(learn.dataX))

    price = coin.close[100:]
    plt.plot(btg_price) # blue
    buy = [btg_price[i] if pred[i] > 5 else None for i in range(len(btg_price)) ] # red # 10퍼증가할 확률 큰 지점

    sell_0 = [btg_price[i] if pred[i] < -3 else None for i in range(len(btg_price)) ] # green # 5퍼 떨어질 확률 큰 지점
    sell_5 = [btg_price[i] if pred[i] < -5 else None for i in range(len(btg_price)) ] # cyan # 5퍼 떨어질 확률 큰 지점
    sell_10 = [btg_price[i] if pred[i] < -10 else None for i in range(len(btg_price)) ] # blue # 10퍼 떨어짐 
    plt.plot(buy, 'ro')


    plt.plot(sell_0, 'go')
    plt.plot(sell_5, 'co')
    plt.plot(sell_10, 'bo')
    plt.show()
    plt.close()
